# %%
# %matplotlib widget

# %%
import sys
import os

# Add the parent folder to sys.path so Python can find online_pca and assignment_code
sys.path.append(os.path.abspath(".."))

from pca_assignment import assignment_code  # this just imports, doesn't run anything

# %%
assignment_code.run_assignment()
# Out:
# Debug mode is enabled. Detailed output will be printed.
# Running Sanger's rule with learning rate schema (1 component): Inverse decay without floor
# Final PCA components:
# Component 1: [-0.69680515 -0.04334964 -0.7159493 ]
# Final generalization error of computed components is: 158.3393841717696
# Computed eigenvectors:
# Leading eigenvector 1: [-0.58996999 -0.78576887  0.18574901], eigenvalue: 162.81775774477055
# Leading eigenvector 2: [-0.15529497  0.33618349  0.9289048 ], eigenvalue: 155.23834329465356
# Leading eigenvector 3: [-0.79235022  0.51918007 -0.32036412], eigenvalue: 153.5659860709695
# Best generalization error we can get is (using 1 leading eigenvectors of validation set): 154.40787711788045
# Average sample is: [-0.05381984  0.01454307 -0.06439867]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Final PCA components:
# Component 1: [-7.00525245e-01  4.63361066e-04 -7.13627470e-01]
# Final generalization error of computed components is: 155.41911398269102
# Computed eigenvectors:
# Leading eigenvector 1: [-0.5030612   0.68688274  0.52452028], eigenvalue: 161.12805025298573
# Leading eigenvector 2: [-0.57378412  0.18840972 -0.7970405 ], eigenvalue: 154.9898675519667
# Leading eigenvector 3: [ 0.64629809  0.70192156 -0.29934079], eigenvalue: 149.32036830230786
# Best generalization error we can get is (using 1 leading eigenvectors of validation set): 152.19986658516112
# Average sample is: [-0.12309609 -0.01506096 -0.13261228]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# end
